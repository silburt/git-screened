# %% [markdown]
# # PDF -> Text scraper
# - https://github.com/pdfminer/pdfminer.six
# - https://stackoverflow.com/questions/25665/python-module-for-converting-pdf-to-text
# - https://stackoverflow.com/questions/5843518/remove-all-special-characters-punctuation-and-spaces-from-string - regular expressions
# - https://pypi.org/simple/ - list of all python packages
#
# ## To Do:
# - using ord, you can convert strings to numbers. Then, using "in" python method is much more efficient. Strings using "in" will match partial, e.g. "of" will match to "thereof", but numbers must be exact matches.

# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io
import re
import numpy as np

# %%
def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    return data

# %%
preproc_text = pdfparser('../../Insight_App/Application:Resume/Insight_Resume.pdf') 
preproc_text
# Out:
# 'ARI SILBURT \nState College, PA · 814.852.9489 \n\nSKILLS \n\n \n\nSEP 2012 – AUG 2017 \n\nEDUCATION/RESEARCH \nSEP 2017 – PRESENT \n\narisilburt@gmail.com · linkedin.com/in/ari-silburt/ · github.com/silburt · silburt.github.io \nLANGUAGES | PYTHON | C | HTML/CSS | LATEX | SQL* | SPARK*  \nTOOLS | NUMPY | PANDAS | SCIKIT-LEARN | KERAS | MATPLOTLIB | GPFLOW* \nMACHINE LEARNING | DEEP LEARNING (CNN, LSTM*) | SUPERVISED \nCLASSIFICATION (XGBOOST, KNN, SVM) | UNSUPERVISED CLUSTERING | LINEAR \nREGRESSION | PCA | NLP* | GAUSSIAN PROCESSES* \n*some experience \nEBERLY POSTDOCTORAL FELLOW, PENN STATE UNIVERSITY \n• DeepMoon: Convolutional Neural Network via Keras to automate crater classification \nfrom lunar images. Transfer-learned lunar model to classify craters on Mercury.  \n• PCA and Gaussian Processes in Python to model the brightness variations of stars and \nextract small, periodic planetary signals buried within. \n \nPHD ASTROPHYSICS, UNIVERSITY OF TORONTO \n• Used XGBoost in C/
# ...

# %%
text = re.sub('[^A-Za-z0-9 /.-]+', '', preproc_text).lower().split()
text
# Out:
# ['ari',
#  'silburt',
#  'state',
#  'college',
#  'pa',
#  '814.852.9489',
#  'skills',
#  'sep',
#  '2012',
#  'aug',
#  '2017',
#  'education/research',
#  'sep',
#  '2017',
#  'present',
#  'arisilburtgmail.com',
#  'linkedin.com/in/ari-silburt/',
#  'github.com/silburt',
#  'silburt.github.io',
#  'languages',
#  'python',
#  'c',
#  'html/css',
#  'latex',
#  'sql',
#  'spark',
#  'tools',
#  'numpy',
#  'pandas',
#  'scikit-learn',
#  'keras',
#  'matplotlib',
#  'gpflow',
#  'machine',
#  'learning',
#  'deep',
#  'learning',
#  'cnn',
#  'lstm',
#  'supervised',
#  'classification',
#  'xgboost',
#  'knn',
#  'svm',
#  'unsupervised',
#  'clustering',
#  'linear',
#  'regression',
#  'pca',
#  'nlp',
#  'gaussian',
#  'processes',
#  'some',
#  'experience',
#  'eberly',
#  'postdoctoral',
#  'fellow',
#  'penn',
#  'state',
#  'university',
#  'deepmoon',
#  'convolutional',
#  'neural',
#  'network',
#  'via',
#  'keras',
#  'to',
#  'automate',
#  'crater',
# ...

# %%
packages = open('utils/popular_packages.txt', 'r').read().lower().split()

# %%
for t in text:
    if t in packages:
        print(t)
    if 'github.com/' in t:
        print(t.split('/')[1])
# Out:
# silburt
# numpy
# pandas
# scikit-learn
# keras
# matplotlib
# keras
# silburt

# %%
from forms import SearchForm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-6520b99a84c5> in <module>()
# ----> 1 from forms import SearchForm
#
# ModuleNotFoundError: No module named 'forms'
